# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q spectral einops thop

import os, time, zipfile, gc
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score, precision_recall_fscore_support
from tensorflow.keras.utils import to_categorical
import spectral

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 10.8 MB/s eta 0:00:00
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ===============================================================
# CONFIG (same style as LhSSN)
# ==============================================================

dataset = 'IP'
windowSize = 25
K = 30
epochs = 100
batch_size = 256
learning_rate = 0.001

split_mode = "ratio"          # ratio / count

train_ratio = 0.05           # if ratio
samples_per_class = 15       # if count

results_folder = "LhSSN_SA_Module_Output"
os.makedirs(results_folder, exist_ok=True)

base = "/content/drive/MyDrive/Colab Notebooks/dataset/"

# ===============================================================
# DATA LOADING
# ==============================================================

def loadData(name):
    if name == 'IP':
        data = sio.loadmat(base+'Indian_pines_corrected.mat')['indian_pines_corrected']
        labels = sio.loadmat(base+'Indian_pines_gt.mat')['indian_pines_gt']
    return data, labels

# ===============================================================
# PCA
# ==============================================================

def applyPCA(X, numComponents):
    reshaped = X.reshape(-1, X.shape[2])
    pca = PCA(n_components=numComponents, whiten=True)
    Xp = pca.fit_transform(reshaped)
    return Xp.reshape(X.shape[0], X.shape[1], numComponents)

# ===============================================================
# PATCH EXTRACTION
# ==============================================================

def padWithZeros(X, margin):
    return np.pad(X, ((margin,margin),(margin,margin),(0,0)), mode='constant')

def createImageCubes(X, y, windowSize=25):
    margin = windowSize // 2
    zeroPaddedX = padWithZeros(X, margin)

    patches = []
    labels = []

    for r in range(margin, zeroPaddedX.shape[0]-margin):
        for c in range(margin, zeroPaddedX.shape[1]-margin):

            patch = zeroPaddedX[r-margin:r+margin+1,
                                c-margin:c+margin+1]

            label = y[r-margin, c-margin]

            if label > 0:
                patches.append(patch)
                labels.append(label-1)

    return np.array(patches), np.array(labels)

# ===============================================================
# SPLIT
# ==============================================================

def splitTrainTestSet(X, y):

    np.random.seed(42)

    train_idx = []
    test_idx = []

    for cls in np.unique(y):

        idx = np.where(y == cls)[0]
        np.random.shuffle(idx)

        if split_mode == "ratio":
            n_train = max(1, int(len(idx)*train_ratio))
        else:
            n_train = min(samples_per_class, len(idx)-1)

        train_idx.extend(idx[:n_train])
        test_idx.extend(idx[n_train:])

    return X[train_idx], X[test_idx], y[train_idx], y[test_idx]

# ===============================================================
# LOAD DATA
# ==============================================================

X, y = loadData(dataset)
X = applyPCA(X, K)
X, y = createImageCubes(X, y, windowSize)

Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y)

num_classes = len(np.unique(y))

ytrain_cat = to_categorical(ytrain, num_classes)
ytest_cat = to_categorical(ytest, num_classes)

print("Train:", Xtrain.shape)
print("Test :", Xtest.shape)
# Out:
# Train: (505, 25, 25, 30)
# Test : (9744, 25, 25, 30)

# %%
# ===============================================================
# MODELLhSSN with conv Channel Attention
# ==============================================================

from tensorflow.keras import layers, models
from einops.layers.tensorflow import Rearrange

def spatial_attention(input_feature):
    kernel_size = 7

    if K.image_data_format() == "channels_first":
        channel = input_feature.shape[1]
        cbam_feature = layers.Permute((2, 3, 1))(input_feature)
    else:
        channel = input_feature.shape[-1]
        cbam_feature = input_feature

    avg_pool = layers.Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    max_pool = layers.Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])

    cbam_feature = layers.Conv2D(filters=1,
                                 kernel_size=kernel_size,
                                 strides=1,
                                 padding='same',
                                 activation='sigmoid',
                                 kernel_initializer='he_normal',
                                 use_bias=False)(concat)

    if K.image_data_format() == "channels_first":
        cbam_feature = layers.Permute((3, 1, 2))(cbam_feature)

    return layers.multiply([input_feature, cbam_feature])
# --------- Build Model (EXACT architecture you used) ---------
def build_model(S, L, num_classes):
    inp = tf.keras.layers.Input((S, S, L, 1))
    # Block 1
    x = tf.keras.layers.Conv3D(filters=8,  kernel_size=(3,3,7), activation='relu')(inp)
    # Block 2
    x = tf.keras.layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu')(x)
    # Block 3
    x = tf.keras.layers.Conv3D(filters=32, kernel_size=(3,3,3), activation='relu')(x)
    # Block 4  (reshape to 2D convs)
    conv3d_shape = x.shape  # (None, H, W, D, C)
    x = tf.keras.layers.Reshape((conv3d_shape[1], conv3d_shape[2],
                                 conv3d_shape[3]*conv3d_shape[4]))(x)
    x = tf.keras.layers.Conv2D(filters=24,  kernel_size=(3,3), activation='relu')(x)


    # Block 5
    x = tf.keras.layers.Conv2D(filters=96,  kernel_size=(3,3), activation='relu')(x)
    ########################################################
    # Spatial Attention
    y1 = layers.MaxPooling2D((2, 2), strides=(1, 1), padding='same',name='MaxPooling2D_y1')(x)
    y2 = layers.AvgPool2D((2, 2), strides=(1, 1), padding='same',name='AvgPool2D_y2')(x)
    concat = layers.Concatenate()([y1, y2])
    y3 = tf.keras.layers.Conv2D(filters=1,  kernel_size=(7,7), padding='same',activation='sigmoid')(concat)

    #y4 = layers.Conv2D(16, (3, 3), padding='same', dilation_rate=2, name='Conv2D_y2')(concat)

    #y4 = layers.BatchNormalization(name='BatchNormalization_y')(y4)
    #y4 = layers.ReLU()(y4)

# Skip Connection (M)
    #z = layers.MaxPooling2D((2, 2), strides=(2, 2), name='MaxPooling2D_z')(x1)
    concat_m = layers.Concatenate()([y3, x])
    gap2 = tf.keras.layers.GlobalAveragePooling2D()(concat_m)

#################################################
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    # Block 6
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu')(x)
    gap1 = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Block 7
    x = layers.Concatenate()([gap1, gap2])


    # Block 7
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    # Output Layer
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    # Adam 0.001 as in your code
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])
    return model

model = build_model(windowSize, K, num_classes)

# Save Summary
with open(results_folder+"/model_summary.txt","w") as f:
    model.summary(print_fn=lambda x: f.write(x+"\n"))

model.summary()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 25, 25,    │          0 │ -                 │
# │ (InputLayer)        │ 30, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 23, 23,    │        512 │ input_layer_1[0]… │
# │                     │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 21, 21,    │      5,776 │ conv3d_3[0][0]    │
# │                     │ 20, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 19, 19,    │     13,856 │ conv3d_4[0][0]    │
# │                     │ 18, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 19, 19,    │          0 │ conv3d_5[0][0]    │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 17, 17,    │    124,440 │ reshape_1[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 15, 15,    │     20,832 │ conv2d_3[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_y1     │ (None, 15, 15,    │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ AvgPool2D_y2        │ (None, 15, 15,    │          0 │ conv2d_4[0][0]    │
# │ (AveragePooling2D)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 15, 15,    │          0 │ MaxPooling2D_y1[… │
# │ (Concatenate)       │ 192)              │            │ AvgPool2D_y2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 7, 7, 96)  │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 15, 15, 1) │      9,409 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 5, 5, 128) │    110,720 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 15, 15,    │          0 │ conv2d_5[0][0],   │
# │ (Concatenate)       │ 97)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_6[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 97)        │          0 │ concatenate_3[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 225)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     28,928 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      1,040 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 323,769 (1.24 MB)
#  Trainable params: 323,769 (1.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#from tensorflow.keras.utils import plot_model
from keras.utils import plot_model, to_categorical
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
import time

# ===============================================================
# TRAIN
# ==============================================================

tic = time.time()

history = model.fit(
    Xtrain, ytrain_cat,
    validation_data=(Xtest, ytest_cat),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2
)

toc = time.time()

train_time = toc - tic

# Save history
np.save(results_folder+"/history.npy", history.history)

# ===============================================================
# PLOTS
# ==============================================================

def save_plot(a,b,title,name):

    plt.figure(figsize=(8,6))
    plt.plot(history.history[a], label='Train')
    plt.plot(history.history[b], label='Validation')
    plt.xlabel("Epochs")
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.savefig(results_folder+"/"+name+".png", dpi=300)
    plt.show()

save_plot("loss","val_loss","Loss Curve","loss_curve")
save_plot("accuracy","val_accuracy","Accuracy Curve","accuracy_curve")

# ===============================================================
# EVALUATION
# ==============================================================

tic = time.time()

pred = model.predict(Xtest)

toc = time.time()

test_time = toc - tic

y_pred = np.argmax(pred, axis=1)

oa = accuracy_score(ytest, y_pred)
kappa = cohen_kappa_score(ytest, y_pred)

cm = confusion_matrix(ytest, y_pred)

each_acc = np.diag(cm)/cm.sum(axis=1)
aa = np.mean(each_acc)

precision, recall, f1, _ = precision_recall_fscore_support(
    ytest, y_pred, average='weighted'
)

# ===============================================================
# SAVE REPORT
# ==============================================================

with open(results_folder+"/results.txt","w") as f:

    f.write(f"Training Time: {train_time:.2f}s\n")
    f.write(f"Testing Time: {test_time:.2f}s\n")
    f.write(f"OA: {oa*100:.2f}\n")
    f.write(f"AA: {aa*100:.2f}\n")
    f.write(f"Kappa: {kappa*100:.2f}\n")
    f.write(f"Precision: {precision*100:.2f}\n")
    f.write(f"Recall: {recall*100:.2f}\n")
    f.write(f"F1-score: {f1*100:.2f}\n\n")

    f.write(classification_report(ytest, y_pred))

# ===============================================================
# CLASSIFICATION MAP
# ==============================================================

Xfull, yfull = loadData(dataset)
Xfull = applyPCA(Xfull, K)

margin = windowSize//2
Xpad = padWithZeros(Xfull, margin)

outputs = np.zeros(yfull.shape)

patches = []
coords = []

for i in range(yfull.shape[0]):
    for j in range(yfull.shape[1]):

        if yfull[i,j] > 0:

            patch = Xpad[i:i+windowSize, j:j+windowSize]
            patches.append(patch)
            coords.append((i,j))

patches = np.array(patches)

pred = model.predict(patches, batch_size=512)
pred = np.argmax(pred, axis=1)

for (i,j),p in zip(coords,pred):
    outputs[i,j] = p+1

spectral.save_rgb(
    results_folder+"/classified_map.jpg",
    outputs.astype(int),
    colors=spectral.spy_colors
)

spectral.save_rgb(
    results_folder+"/ground_truth.jpg",
    yfull.astype(int),
    colors=spectral.spy_colors
)

# ===============================================================
# ZIP
# ==============================================================

zip_name = "LhSSN_SA_Module_Output.zip"

with zipfile.ZipFile(zip_name,'w') as zipf:
    for file in os.listdir(results_folder):
        zipf.write(results_folder+"/"+file, arcname=file)

print("DONE.")
print("ZIP FILE:", zip_name)
# Out:
# Epoch 1/100
# 2/2 - 50s - 25s/step - accuracy: 0.1030 - loss: 2.7548 - val_accuracy: 0.2394 - val_loss: 2.6279
# Epoch 2/100
# 2/2 - 3s - 2s/step - accuracy: 0.2020 - loss: 2.7864 - val_accuracy: 0.2394 - val_loss: 2.5666
# Epoch 3/100
# 2/2 - 3s - 2s/step - accuracy: 0.2099 - loss: 2.6150 - val_accuracy: 0.2394 - val_loss: 2.6255
# Epoch 4/100
# 2/2 - 5s - 3s/step - accuracy: 0.2059 - loss: 2.6225 - val_accuracy: 0.2394 - val_loss: 2.5664
# Epoch 5/100
# 2/2 - 3s - 2s/step - accuracy: 0.1960 - loss: 2.5481 - val_accuracy: 0.2394 - val_loss: 2.4355
# Epoch 6/100
# 2/2 - 3s - 2s/step - accuracy: 0.2198 - loss: 2.5103 - val_accuracy: 0.2394 - val_loss: 2.3977
# Epoch 7/100
# 2/2 - 3s - 2s/step - accuracy: 0.2040 - loss: 2.4947 - val_accuracy: 0.2394 - val_loss: 2.3947
# Epoch 8/100
# 2/2 - 3s - 2s/step - accuracy: 0.2198 - loss: 2.4466 - val_accuracy: 0.2394 - val_loss: 2.4034
# Epoch 9/100
# 2/2 - 3s - 2s/step - accuracy: 0.2079 - loss: 2.4432 - val_accuracy: 0.2394 - val_loss: 2.3340
# Epoch 10/100
# 2/2 - 3s - 2s/step - accuracy: 0.2238 - loss: 2.3667 - val_accuracy: 0.2394 - val_loss: 2.2495
# Epoch 11/100
# 2/2 - 3s - 2s/step - accuracy: 0.2198 - loss: 2.3879 - val_accuracy: 0.2394 - val_loss: 2.2075
# Epoch 12/100
# 2/2 - 3s - 2s/step - accuracy: 0.2554 - loss: 2.2836 - val_accuracy: 0.2394 - val_loss: 2.1899
# Epoch 13/100
# 2/2 - 3s - 2s/step - accuracy: 0.2495 - loss: 2.2504 - val_accuracy: 0.2394 - val_loss: 2.1311
# Epoch 14/100
# 2/2 - 3s - 2s/step - accuracy: 0.2752 - loss: 2.2188 - val_accuracy: 0.2905 - val_loss: 2.0792
# Epoch 15/100
# 2/2 - 3s - 2s/step - accuracy: 0.2772 - loss: 2.1547 - val_accuracy: 0.3222 - val_loss: 2.0300
# Epoch 16/100
# 2/2 - 3s - 2s/step - accuracy: 0.2713 - loss: 2.1168 - val_accuracy: 0.3243 - val_loss: 1.9651
# Epoch 17/100
# 2/2 - 3s - 2s/step - accuracy: 0.2851 - loss: 2.0496 - val_accuracy: 0.3220 - val_loss: 1.8815
# Epoch 18/100
# 2/2 - 3s - 2s/step - accuracy: 0.2931 - loss: 1.9942 - val_accuracy: 0.3109 - val_loss: 1.8729
# Epoch 19/100
# 2/2 - 3s - 2s/step - accuracy: 0.3030 - loss: 1.9530 - val_accuracy: 0.3312 - val_loss: 1.8132
# Epoch 20/100
# 2/2 - 5s - 3s/step - accuracy: 0.3050 - loss: 1.9166 - val_accuracy: 0.3471 - val_loss: 1.7950
# Epoch 21/100
# 2/2 - 3s - 2s/step - accuracy: 0.3386 - loss: 1.8606 - val_accuracy: 0.3191 - val_loss: 1.7555
# Epoch 22/100
# 2/2 - 3s - 2s/step - accuracy: 0.3525 - loss: 1.8087 - val_accuracy: 0.3228 - val_loss: 1.7143
# Epoch 23/100
# 2/2 - 3s - 2s/step - accuracy: 0.3505 - loss: 1.8085 - val_accuracy: 0.3905 - val_loss: 1.6814
# Epoch 24/100
# 2/2 - 3s - 2s/step - accuracy: 0.3505 - loss: 1.7622 - val_accuracy: 0.3717 - val_loss: 1.6186
# Epoch 25/100
# 2/2 - 3s - 2s/step - accuracy: 0.4020 - loss: 1.6646 - val_accuracy: 0.3727 - val_loss: 1.5451
# Epoch 26/100
# 2/2 - 3s - 2s/step - accuracy: 0.4059 - loss: 1.6662 - val_accuracy: 0.4132 - val_loss: 1.4940
# Epoch 27/100
# 2/2 - 3s - 2s/step - accuracy: 0.4000 - loss: 1.6343 - val_accuracy: 0.4789 - val_loss: 1.4738
# Epoch 28/100
# 2/2 - 3s - 2s/step - accuracy: 0.4475 - loss: 1.5415 - val_accuracy: 0.5235 - val_loss: 1.3898
# Epoch 29/100
# 2/2 - 3s - 2s/step - accuracy: 0.4772 - loss: 1.5076 - val_accuracy: 0.5523 - val_loss: 1.3079
# Epoch 30/100
# 2/2 - 3s - 2s/step - accuracy: 0.4931 - loss: 1.3976 - val_accuracy: 0.5472 - val_loss: 1.2686
# Epoch 31/100
# 2/2 - 3s - 2s/step - accuracy: 0.5109 - loss: 1.3619 - val_accuracy: 0.5970 - val_loss: 1.1870
# Epoch 32/100
# 2/2 - 3s - 2s/step - accuracy: 0.5545 - loss: 1.3343 - val_accuracy: 0.5824 - val_loss: 1.1564
# Epoch 33/100
# 2/2 - 3s - 2s/step - accuracy: 0.5624 - loss: 1.2580 - val_accuracy: 0.5339 - val_loss: 1.2452
# Epoch 34/100
# 2/2 - 5s - 3s/step - accuracy: 0.5525 - loss: 1.2812 - val_accuracy: 0.6034 - val_loss: 1.1389
# Epoch 35/100
# 2/2 - 3s - 2s/step - accuracy: 0.5485 - loss: 1.2502 - val_accuracy: 0.6156 - val_loss: 1.0657
# Epoch 36/100
# 2/2 - 3s - 2s/step - accuracy: 0.5822 - loss: 1.1554 - val_accuracy: 0.6141 - val_loss: 1.0793
# Epoch 37/100
# 2/2 - 3s - 2s/step - accuracy: 0.6059 - loss: 1.1490 - val_accuracy: 0.6636 - val_loss: 1.0109
# Epoch 38/100
# 2/2 - 3s - 2s/step - accuracy: 0.6376 - loss: 1.1121 - val_accuracy: 0.6782 - val_loss: 0.9943
# Epoch 39/100
# 2/2 - 3s - 2s/step - accuracy: 0.6396 - loss: 1.0283 - val_accuracy: 0.7054 - val_loss: 0.9482
# Epoch 40/100
# 2/2 - 4s - 2s/step - accuracy: 0.6752 - loss: 0.9933 - val_accuracy: 0.7126 - val_loss: 0.9250
# Epoch 41/100
# 2/2 - 3s - 2s/step - accuracy: 0.6693 - loss: 0.9796 - val_accuracy: 0.7303 - val_loss: 0.9007
# Epoch 42/100
# 2/2 - 3s - 2s/step - accuracy: 0.7010 - loss: 0.9309 - val_accuracy: 0.7551 - val_loss: 0.8620
# Epoch 43/100
# 2/2 - 3s - 2s/step - accuracy: 0.7188 - loss: 0.9027 - val_accuracy: 0.7135 - val_loss: 0.9891
# Epoch 44/100
# 2/2 - 4s - 2s/step - accuracy: 0.6614 - loss: 1.0238 - val_accuracy: 0.7547 - val_loss: 0.8600
# Epoch 45/100
# 2/2 - 3s - 2s/step - accuracy: 0.6851 - loss: 1.0715 - val_accuracy: 0.7641 - val_loss: 0.9052
# Epoch 46/100
# 2/2 - 3s - 2s/step - accuracy: 0.7584 - loss: 0.8811 - val_accuracy: 0.7268 - val_loss: 0.9216
# Epoch 47/100
# 2/2 - 3s - 2s/step - accuracy: 0.6891 - loss: 0.9643 - val_accuracy: 0.7585 - val_loss: 0.8308
# Epoch 48/100
# 2/2 - 4s - 2s/step - accuracy: 0.7465 - loss: 0.8251 - val_accuracy: 0.7772 - val_loss: 0.8302
# Epoch 49/100
# 2/2 - 3s - 2s/step - accuracy: 0.7347 - loss: 0.8774 - val_accuracy: 0.7838 - val_loss: 0.8178
# Epoch 50/100
# 2/2 - 5s - 3s/step - accuracy: 0.7703 - loss: 0.7860 - val_accuracy: 0.7888 - val_loss: 0.7672
# Epoch 51/100
# 2/2 - 3s - 2s/step - accuracy: 0.7762 - loss: 0.7551 - val_accuracy: 0.7938 - val_loss: 0.7665
# Epoch 52/100
# 2/2 - 3s - 2s/step - accuracy: 0.7980 - loss: 0.7308 - val_accuracy: 0.8104 - val_loss: 0.6867
# Epoch 53/100
# 2/2 - 3s - 2s/step - accuracy: 0.8000 - loss: 0.7117 - val_accuracy: 0.8231 - val_loss: 0.6657
# Epoch 54/100
# 2/2 - 3s - 2s/step - accuracy: 0.8000 - loss: 0.7074 - val_accuracy: 0.8309 - val_loss: 0.6507
# Epoch 55/100
# 2/2 - 3s - 2s/step - accuracy: 0.8119 - loss: 0.6394 - val_accuracy: 0.8258 - val_loss: 0.6387
# Epoch 56/100
# 2/2 - 4s - 2s/step - accuracy: 0.8198 - loss: 0.6195 - val_accuracy: 0.8298 - val_loss: 0.6268
# Epoch 57/100
# 2/2 - 3s - 2s/step - accuracy: 0.8515 - loss: 0.5566 - val_accuracy: 0.8473 - val_loss: 0.5892
# Epoch 58/100
# 2/2 - 3s - 2s/step - accuracy: 0.8634 - loss: 0.5270 - val_accuracy: 0.8528 - val_loss: 0.6036
# Epoch 59/100
# 2/2 - 3s - 2s/step - accuracy: 0.8396 - loss: 0.5453 - val_accuracy: 0.8541 - val_loss: 0.5836
# Epoch 60/100
# 2/2 - 7s - 4s/step - accuracy: 0.8396 - loss: 0.5355 - val_accuracy: 0.8608 - val_loss: 0.5446
# Epoch 61/100
# 2/2 - 3s - 2s/step - accuracy: 0.8356 - loss: 0.5060 - val_accuracy: 0.8551 - val_loss: 0.5466
# Epoch 62/100
# 2/2 - 4s - 2s/step - accuracy: 0.8772 - loss: 0.4382 - val_accuracy: 0.8612 - val_loss: 0.5077
# Epoch 63/100
# 2/2 - 4s - 2s/step - accuracy: 0.8693 - loss: 0.4454 - val_accuracy: 0.8715 - val_loss: 0.4747
# Epoch 64/100
# 2/2 - 3s - 2s/step - accuracy: 0.8970 - loss: 0.4123 - val_accuracy: 0.8651 - val_loss: 0.5257
# Epoch 65/100
# 2/2 - 3s - 2s/step - accuracy: 0.8832 - loss: 0.4033 - val_accuracy: 0.8787 - val_loss: 0.4682
# Epoch 66/100
# 2/2 - 4s - 2s/step - accuracy: 0.8871 - loss: 0.3628 - val_accuracy: 0.8762 - val_loss: 0.4699
# Epoch 67/100
# 2/2 - 4s - 2s/step - accuracy: 0.8891 - loss: 0.3888 - val_accuracy: 0.8814 - val_loss: 0.4526
# Epoch 68/100
# 2/2 - 3s - 2s/step - accuracy: 0.8871 - loss: 0.3905 - val_accuracy: 0.8830 - val_loss: 0.5118
# Epoch 69/100
# 2/2 - 3s - 2s/step - accuracy: 0.8772 - loss: 0.3879 - val_accuracy: 0.8956 - val_loss: 0.4152
# Epoch 70/100
# 2/2 - 4s - 2s/step - accuracy: 0.8733 - loss: 0.4356 - val_accuracy: 0.8919 - val_loss: 0.4093
# Epoch 71/100
# 2/2 - 4s - 2s/step - accuracy: 0.8792 - loss: 0.3795 - val_accuracy: 0.8689 - val_loss: 0.5148
# Epoch 72/100
# 2/2 - 3s - 2s/step - accuracy: 0.8614 - loss: 0.4464 - val_accuracy: 0.8800 - val_loss: 0.4505
# Epoch 73/100
# 2/2 - 3s - 2s/step - accuracy: 0.8950 - loss: 0.3713 - val_accuracy: 0.8764 - val_loss: 0.4693
# Epoch 74/100
# 2/2 - 4s - 2s/step - accuracy: 0.8970 - loss: 0.3540 - val_accuracy: 0.8876 - val_loss: 0.3926
# Epoch 75/100
# 2/2 - 4s - 2s/step - accuracy: 0.9030 - loss: 0.3387 - val_accuracy: 0.8951 - val_loss: 0.3949
# Epoch 76/100
# 2/2 - 3s - 2s/step - accuracy: 0.9129 - loss: 0.3110 - val_accuracy: 0.8881 - val_loss: 0.4216
# Epoch 77/100
# 2/2 - 3s - 2s/step - accuracy: 0.9188 - loss: 0.2948 - val_accuracy: 0.9058 - val_loss: 0.3662
# Epoch 78/100
# 2/2 - 4s - 2s/step - accuracy: 0.9386 - loss: 0.2370 - val_accuracy: 0.9070 - val_loss: 0.3864
# Epoch 79/100
# 2/2 - 4s - 2s/step - accuracy: 0.9069 - loss: 0.2728 - val_accuracy: 0.9191 - val_loss: 0.3547
# Epoch 80/100
# 2/2 - 3s - 2s/step - accuracy: 0.9129 - loss: 0.2534 - val_accuracy: 0.9119 - val_loss: 0.4002
# Epoch 81/100
# 2/2 - 3s - 2s/step - accuracy: 0.9129 - loss: 0.2511 - val_accuracy: 0.9201 - val_loss: 0.3607
# Epoch 82/100
# 2/2 - 4s - 2s/step - accuracy: 0.9347 - loss: 0.2291 - val_accuracy: 0.9176 - val_loss: 0.3750
# Epoch 83/100
# 2/2 - 4s - 2s/step - accuracy: 0.9248 - loss: 0.2518 - val_accuracy: 0.9119 - val_loss: 0.4303
# Epoch 84/100
# 2/2 - 3s - 2s/step - accuracy: 0.9149 - loss: 0.2325 - val_accuracy: 0.9155 - val_loss: 0.4055
# Epoch 85/100
# 2/2 - 3s - 2s/step - accuracy: 0.9287 - loss: 0.2806 - val_accuracy: 0.9211 - val_loss: 0.3843
# Epoch 86/100
# 2/2 - 4s - 2s/step - accuracy: 0.9208 - loss: 0.2509 - val_accuracy: 0.9100 - val_loss: 0.4060
# Epoch 87/100
# 2/2 - 5s - 3s/step - accuracy: 0.9267 - loss: 0.2463 - val_accuracy: 0.9258 - val_loss: 0.3022
# Epoch 88/100
# 2/2 - 3s - 2s/step - accuracy: 0.9426 - loss: 0.1882 - val_accuracy: 0.9284 - val_loss: 0.2796
# Epoch 89/100
# 2/2 - 3s - 2s/step - accuracy: 0.9426 - loss: 0.1746 - val_accuracy: 0.9268 - val_loss: 0.2967
# Epoch 90/100
# 2/2 - 4s - 2s/step - accuracy: 0.9465 - loss: 0.1826 - val_accuracy: 0.9290 - val_loss: 0.2906
# Epoch 91/100
# 2/2 - 3s - 2s/step - accuracy: 0.9446 - loss: 0.1705 - val_accuracy: 0.9322 - val_loss: 0.2618
# Epoch 92/100
# 2/2 - 3s - 2s/step - accuracy: 0.9386 - loss: 0.1825 - val_accuracy: 0.9312 - val_loss: 0.2631
# Epoch 93/100
# 2/2 - 4s - 2s/step - accuracy: 0.9624 - loss: 0.1464 - val_accuracy: 0.9338 - val_loss: 0.2662
# Epoch 94/100
# 2/2 - 4s - 2s/step - accuracy: 0.9505 - loss: 0.1577 - val_accuracy: 0.9331 - val_loss: 0.2817
# Epoch 95/100
# 2/2 - 3s - 2s/step - accuracy: 0.9703 - loss: 0.1218 - val_accuracy: 0.9287 - val_loss: 0.3055
# Epoch 96/100
# 2/2 - 4s - 2s/step - accuracy: 0.9564 - loss: 0.1551 - val_accuracy: 0.9333 - val_loss: 0.2733
# Epoch 97/100
# 2/2 - 4s - 2s/step - accuracy: 0.9406 - loss: 0.1897 - val_accuracy: 0.9318 - val_loss: 0.2742
# Epoch 98/100
# 2/2 - 4s - 2s/step - accuracy: 0.9525 - loss: 0.1728 - val_accuracy: 0.9314 - val_loss: 0.2869
# Epoch 99/100
# 2/2 - 3s - 2s/step - accuracy: 0.9584 - loss: 0.1381 - val_accuracy: 0.9304 - val_loss: 0.3089
# Epoch 100/100
# 2/2 - 3s - 2s/step - accuracy: 0.9564 - loss: 0.1334 - val_accuracy: 0.9298 - val_loss: 0.3405
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 194ms/step
