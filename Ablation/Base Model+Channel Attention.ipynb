# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q spectral einops thop

import os, time, zipfile, gc
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score, precision_recall_fscore_support
from tensorflow.keras.utils import to_categorical
import spectral

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ===============================================================
# CONFIG (same style as LhSSN)
# ==============================================================

dataset = 'IP'
windowSize = 25
K = 30
epochs = 100
batch_size = 256
learning_rate = 0.001

split_mode = "ratio"          # ratio / count

train_ratio = 0.05           # if ratio
samples_per_class = 15       # if count

results_folder = "LhSSN_SA_Module_Output"
os.makedirs(results_folder, exist_ok=True)

base = "/content/drive/MyDrive/Colab Notebooks/dataset/"

# ===============================================================
# DATA LOADING
# ==============================================================

def loadData(name):
    if name == 'IP':
        data = sio.loadmat(base+'Indian_pines_corrected.mat')['indian_pines_corrected']
        labels = sio.loadmat(base+'Indian_pines_gt.mat')['indian_pines_gt']
    return data, labels

# ===============================================================
# PCA
# ==============================================================

def applyPCA(X, numComponents):
    reshaped = X.reshape(-1, X.shape[2])
    pca = PCA(n_components=numComponents, whiten=True)
    Xp = pca.fit_transform(reshaped)
    return Xp.reshape(X.shape[0], X.shape[1], numComponents)

# ===============================================================
# PATCH EXTRACTION
# ==============================================================

def padWithZeros(X, margin):
    return np.pad(X, ((margin,margin),(margin,margin),(0,0)), mode='constant')

def createImageCubes(X, y, windowSize=25):
    margin = windowSize // 2
    zeroPaddedX = padWithZeros(X, margin)

    patches = []
    labels = []

    for r in range(margin, zeroPaddedX.shape[0]-margin):
        for c in range(margin, zeroPaddedX.shape[1]-margin):

            patch = zeroPaddedX[r-margin:r+margin+1,
                                c-margin:c+margin+1]

            label = y[r-margin, c-margin]

            if label > 0:
                patches.append(patch)
                labels.append(label-1)

    return np.array(patches), np.array(labels)

# ===============================================================
# SPLIT
# ==============================================================

def splitTrainTestSet(X, y):

    np.random.seed(42)

    train_idx = []
    test_idx = []

    for cls in np.unique(y):

        idx = np.where(y == cls)[0]
        np.random.shuffle(idx)

        if split_mode == "ratio":
            n_train = max(1, int(len(idx)*train_ratio))
        else:
            n_train = min(samples_per_class, len(idx)-1)

        train_idx.extend(idx[:n_train])
        test_idx.extend(idx[n_train:])

    return X[train_idx], X[test_idx], y[train_idx], y[test_idx]

# ===============================================================
# LOAD DATA
# ==============================================================

X, y = loadData(dataset)
X = applyPCA(X, K)
X, y = createImageCubes(X, y, windowSize)

Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y)

num_classes = len(np.unique(y))

ytrain_cat = to_categorical(ytrain, num_classes)
ytest_cat = to_categorical(ytest, num_classes)

print("Train:", Xtrain.shape)
print("Test :", Xtest.shape)
# Out:
# Train: (505, 25, 25, 30)
# Test : (9744, 25, 25, 30)

# %%
# ===============================================================
# MODELLhSSN with conv Channel Attention
# ==============================================================

from tensorflow.keras import layers, models
from einops.layers.tensorflow import Rearrange

def channel_attention(input_feature):
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    max_pool = layers.GlobalMaxPooling2D()(input_feature)

    combined = layers.concatenate([avg_pool, max_pool])
    combined = layers.Reshape((1, 1, combined.shape[1]))(combined)

    dense = layers.Dense(combined.shape[3] // 8, activation='relu')(combined)
    dense = layers.Dense(input_feature.shape[-1], activation='sigmoid')(dense)

    attention = layers.Reshape((1, 1, input_feature.shape[-1]))(dense)
    return layers.multiply([input_feature, attention])

# --------- Build Model (EXACT architecture you used) ---------
def build_model(S, L, num_classes):
    inp = tf.keras.layers.Input((S, S, L, 1))
    # Block 1
    x = tf.keras.layers.Conv3D(filters=8,  kernel_size=(3,3,7), activation='relu')(inp)
    # Block 2
    x = tf.keras.layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu')(x)
    # Block 3
    x = tf.keras.layers.Conv3D(filters=32, kernel_size=(3,3,3), activation='relu')(x)
    # Block 4  (reshape to 2D convs)
    conv3d_shape = x.shape  # (None, H, W, D, C)
    x = tf.keras.layers.Reshape((conv3d_shape[1], conv3d_shape[2],
                                 conv3d_shape[3]*conv3d_shape[4]))(x)
    x = tf.keras.layers.Conv2D(filters=24,  kernel_size=(3,3), activation='relu')(x)


    # Block 5
    x = tf.keras.layers.Conv2D(filters=96,  kernel_size=(3,3), activation='relu')(x)
    #####################################################
    y_chan = channel_attention(x)
    gap_3 = tf.keras.layers.GlobalAveragePooling2D()(y_chan)
    ########################################################
    '''
    # Spatial Attention
    x1 = layers.BatchNormalization(name='BatchNormalization_4')(x)

    y1 = layers.MaxPooling2D((2, 2), padding="same", strides=(1, 1), name='MaxPooling2D_y1')(x1)
    y2 = layers.AvgPool2D((2, 2), padding="same", strides=(1, 1), name='AvgPool2D_y2')(x1)
    concat = layers.Concatenate()([y1, y2])

    y4 = layers.Conv2D(32, (3, 3), padding='valid', dilation_rate=2, name='Conv2D_y2')(concat)

    y4 = layers.BatchNormalization(name='BatchNormalization_y')(y4)
    #y4 = layers.ReLU()(y4)
    y4 = tf.keras.activations.gelu(y4)

    # Channel Attention
    # Skip Connection (M)
    #concat_m = layers.Concatenate()([y4, x1])
    z = layers.MaxPooling2D((2, 2), strides=(2, 2), name='MaxPooling2D_z')(y4)
    gap_2 = tf.keras.layers.GlobalAveragePooling2D()(z)'''

#################################################
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    # Block 6
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu')(x)
    gap_1 = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Block 7
    x = layers.Concatenate()([gap_1, gap_3])


    # Block 7
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    # Output Layer
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    # Adam 0.001 as in your code
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])
    return model

model = build_model(windowSize, K, num_classes)

# Save Summary
with open(results_folder+"/model_summary.txt","w") as f:
    model.summary(print_fn=lambda x: f.write(x+"\n"))

model.summary()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 25, 25,    │          0 │ -                 │
# │ (InputLayer)        │ 30, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 23, 23,    │        512 │ input_layer[0][0] │
# │                     │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 21, 21,    │      5,776 │ conv3d[0][0]      │
# │                     │ 20, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 19, 19,    │     13,856 │ conv3d_1[0][0]    │
# │                     │ 18, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 19, 19,    │          0 │ conv3d_2[0][0]    │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 17, 17,    │    124,440 │ reshape[0][0]     │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 15, 15,    │     20,832 │ conv2d[0][0]      │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ conv2d_1[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 96)        │          0 │ conv2d_1[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 192)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 192) │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 24)  │      4,632 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 96)  │      2,400 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 7, 7, 96)  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 96)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 5, 5, 128) │    110,720 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 15, 15,    │          0 │ conv2d_1[0][0],   │
# │                     │ 96)               │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ multiply[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 224)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     28,800 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │      1,040 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 321,264 (1.23 MB)
#  Trainable params: 321,264 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#from tensorflow.keras.utils import plot_model
from keras.utils import plot_model, to_categorical
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
import time

# ===============================================================
# TRAIN
# ==============================================================

tic = time.time()

history = model.fit(
    Xtrain, ytrain_cat,
    validation_data=(Xtest, ytest_cat),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2
)

toc = time.time()

train_time = toc - tic

# Save history
np.save(results_folder+"/history.npy", history.history)

# ===============================================================
# PLOTS
# ==============================================================

def save_plot(a,b,title,name):

    plt.figure(figsize=(8,6))
    plt.plot(history.history[a], label='Train')
    plt.plot(history.history[b], label='Validation')
    plt.xlabel("Epochs")
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.savefig(results_folder+"/"+name+".png", dpi=300)
    plt.show()

save_plot("loss","val_loss","Loss Curve","loss_curve")
save_plot("accuracy","val_accuracy","Accuracy Curve","accuracy_curve")

# ===============================================================
# EVALUATION
# ==============================================================

tic = time.time()

pred = model.predict(Xtest)

toc = time.time()

test_time = toc - tic

y_pred = np.argmax(pred, axis=1)

oa = accuracy_score(ytest, y_pred)
kappa = cohen_kappa_score(ytest, y_pred)

cm = confusion_matrix(ytest, y_pred)

each_acc = np.diag(cm)/cm.sum(axis=1)
aa = np.mean(each_acc)

precision, recall, f1, _ = precision_recall_fscore_support(
    ytest, y_pred, average='weighted'
)

# ===============================================================
# SAVE REPORT
# ==============================================================

with open(results_folder+"/results.txt","w") as f:

    f.write(f"Training Time: {train_time:.2f}s\n")
    f.write(f"Testing Time: {test_time:.2f}s\n")
    f.write(f"OA: {oa*100:.2f}\n")
    f.write(f"AA: {aa*100:.2f}\n")
    f.write(f"Kappa: {kappa*100:.2f}\n")
    f.write(f"Precision: {precision*100:.2f}\n")
    f.write(f"Recall: {recall*100:.2f}\n")
    f.write(f"F1-score: {f1*100:.2f}\n\n")

    f.write(classification_report(ytest, y_pred))

# ===============================================================
# CLASSIFICATION MAP
# ==============================================================

Xfull, yfull = loadData(dataset)
Xfull = applyPCA(Xfull, K)

margin = windowSize//2
Xpad = padWithZeros(Xfull, margin)

outputs = np.zeros(yfull.shape)

patches = []
coords = []

for i in range(yfull.shape[0]):
    for j in range(yfull.shape[1]):

        if yfull[i,j] > 0:

            patch = Xpad[i:i+windowSize, j:j+windowSize]
            patches.append(patch)
            coords.append((i,j))

patches = np.array(patches)

pred = model.predict(patches, batch_size=512)
pred = np.argmax(pred, axis=1)

for (i,j),p in zip(coords,pred):
    outputs[i,j] = p+1

spectral.save_rgb(
    results_folder+"/classified_map.jpg",
    outputs.astype(int),
    colors=spectral.spy_colors
)

spectral.save_rgb(
    results_folder+"/ground_truth.jpg",
    yfull.astype(int),
    colors=spectral.spy_colors
)

# ===============================================================
# ZIP
# ==============================================================

zip_name = "LhSSN_SA_Module_Output.zip"

with zipfile.ZipFile(zip_name,'w') as zipf:
    for file in os.listdir(results_folder):
        zipf.write(results_folder+"/"+file, arcname=file)

print("DONE.")
print("ZIP FILE:", zip_name)
# Out:
# Epoch 1/100
# 2/2 - 50s - 25s/step - accuracy: 0.1069 - loss: 2.7293 - val_accuracy: 0.2394 - val_loss: 2.6144
# Epoch 2/100
# 2/2 - 3s - 2s/step - accuracy: 0.1465 - loss: 2.7205 - val_accuracy: 0.2394 - val_loss: 2.6490
# Epoch 3/100
# 2/2 - 3s - 2s/step - accuracy: 0.1426 - loss: 2.6581 - val_accuracy: 0.2394 - val_loss: 2.6212
# Epoch 4/100
# 2/2 - 3s - 2s/step - accuracy: 0.1624 - loss: 2.6234 - val_accuracy: 0.2394 - val_loss: 2.5018
# Epoch 5/100
# 2/2 - 3s - 2s/step - accuracy: 0.1921 - loss: 2.5907 - val_accuracy: 0.2394 - val_loss: 2.4648
# Epoch 6/100
# 2/2 - 3s - 2s/step - accuracy: 0.2099 - loss: 2.5410 - val_accuracy: 0.2394 - val_loss: 2.4800
# Epoch 7/100
# 2/2 - 3s - 2s/step - accuracy: 0.2020 - loss: 2.5146 - val_accuracy: 0.2394 - val_loss: 2.4561
# Epoch 8/100
# 2/2 - 3s - 2s/step - accuracy: 0.2158 - loss: 2.4956 - val_accuracy: 0.2394 - val_loss: 2.4108
# Epoch 9/100
# 2/2 - 3s - 2s/step - accuracy: 0.2475 - loss: 2.4730 - val_accuracy: 0.2394 - val_loss: 2.4065
# Epoch 10/100
# 2/2 - 3s - 2s/step - accuracy: 0.2020 - loss: 2.4628 - val_accuracy: 0.2394 - val_loss: 2.3881
# Epoch 11/100
# 2/2 - 3s - 2s/step - accuracy: 0.2040 - loss: 2.4092 - val_accuracy: 0.2394 - val_loss: 2.2937
# Epoch 12/100
# 2/2 - 3s - 2s/step - accuracy: 0.1980 - loss: 2.3976 - val_accuracy: 0.2394 - val_loss: 2.2726
# Epoch 13/100
# 2/2 - 4s - 2s/step - accuracy: 0.2238 - loss: 2.2959 - val_accuracy: 0.2394 - val_loss: 2.2073
# Epoch 14/100
# 2/2 - 6s - 3s/step - accuracy: 0.2356 - loss: 2.2434 - val_accuracy: 0.2394 - val_loss: 2.1342
# Epoch 15/100
# 2/2 - 4s - 2s/step - accuracy: 0.2277 - loss: 2.2239 - val_accuracy: 0.2394 - val_loss: 2.1278
# Epoch 16/100
# 2/2 - 4s - 2s/step - accuracy: 0.2416 - loss: 2.1742 - val_accuracy: 0.2394 - val_loss: 2.0772
# Epoch 17/100
# 2/2 - 4s - 2s/step - accuracy: 0.2416 - loss: 2.1572 - val_accuracy: 0.2394 - val_loss: 1.9952
# Epoch 18/100
# 2/2 - 4s - 2s/step - accuracy: 0.2475 - loss: 2.0505 - val_accuracy: 0.3304 - val_loss: 1.9323
# Epoch 19/100
# 2/2 - 4s - 2s/step - accuracy: 0.3010 - loss: 1.9792 - val_accuracy: 0.3249 - val_loss: 1.8530
# Epoch 20/100
# 2/2 - 4s - 2s/step - accuracy: 0.3386 - loss: 1.9036 - val_accuracy: 0.3594 - val_loss: 1.7598
# Epoch 21/100
# 2/2 - 4s - 2s/step - accuracy: 0.3406 - loss: 1.8485 - val_accuracy: 0.3863 - val_loss: 1.7217
# Epoch 22/100
# 2/2 - 3s - 2s/step - accuracy: 0.3723 - loss: 1.7667 - val_accuracy: 0.3714 - val_loss: 1.6546
# Epoch 23/100
# 2/2 - 3s - 2s/step - accuracy: 0.3624 - loss: 1.7279 - val_accuracy: 0.4382 - val_loss: 1.5815
# Epoch 24/100
# 2/2 - 4s - 2s/step - accuracy: 0.4238 - loss: 1.6833 - val_accuracy: 0.4991 - val_loss: 1.5239
# Epoch 25/100
# 2/2 - 4s - 2s/step - accuracy: 0.4416 - loss: 1.5935 - val_accuracy: 0.4478 - val_loss: 1.4774
# Epoch 26/100
# 2/2 - 3s - 2s/step - accuracy: 0.4574 - loss: 1.5489 - val_accuracy: 0.5366 - val_loss: 1.4020
# Epoch 27/100
# 2/2 - 3s - 2s/step - accuracy: 0.4594 - loss: 1.5115 - val_accuracy: 0.5521 - val_loss: 1.3602
# Epoch 28/100
# 2/2 - 3s - 2s/step - accuracy: 0.4891 - loss: 1.4322 - val_accuracy: 0.5655 - val_loss: 1.2994
# Epoch 29/100
# 2/2 - 3s - 2s/step - accuracy: 0.5386 - loss: 1.3013 - val_accuracy: 0.5641 - val_loss: 1.2540
# Epoch 30/100
# 2/2 - 3s - 2s/step - accuracy: 0.5545 - loss: 1.3303 - val_accuracy: 0.6255 - val_loss: 1.2221
# Epoch 31/100
# 2/2 - 3s - 2s/step - accuracy: 0.5762 - loss: 1.2554 - val_accuracy: 0.6413 - val_loss: 1.1311
# Epoch 32/100
# 2/2 - 6s - 3s/step - accuracy: 0.5861 - loss: 1.1969 - val_accuracy: 0.6508 - val_loss: 1.0914
# Epoch 33/100
# 2/2 - 3s - 2s/step - accuracy: 0.6099 - loss: 1.2077 - val_accuracy: 0.6415 - val_loss: 1.1131
# Epoch 34/100
# 2/2 - 3s - 2s/step - accuracy: 0.6139 - loss: 1.1511 - val_accuracy: 0.6639 - val_loss: 1.0556
# Epoch 35/100
# 2/2 - 3s - 2s/step - accuracy: 0.6475 - loss: 1.0643 - val_accuracy: 0.6691 - val_loss: 1.0029
# Epoch 36/100
# 2/2 - 4s - 2s/step - accuracy: 0.6455 - loss: 1.0365 - val_accuracy: 0.7033 - val_loss: 0.9362
# Epoch 37/100
# 2/2 - 3s - 2s/step - accuracy: 0.6653 - loss: 0.9745 - val_accuracy: 0.7257 - val_loss: 0.9083
# Epoch 38/100
# 2/2 - 3s - 2s/step - accuracy: 0.6911 - loss: 0.9399 - val_accuracy: 0.7461 - val_loss: 0.8463
# Epoch 39/100
# 2/2 - 3s - 2s/step - accuracy: 0.7366 - loss: 0.8273 - val_accuracy: 0.7680 - val_loss: 0.8024
# Epoch 40/100
# 2/2 - 4s - 2s/step - accuracy: 0.7287 - loss: 0.8360 - val_accuracy: 0.7751 - val_loss: 0.7522
# Epoch 41/100
# 2/2 - 3s - 2s/step - accuracy: 0.7287 - loss: 0.8097 - val_accuracy: 0.7711 - val_loss: 0.7443
# Epoch 42/100
# 2/2 - 3s - 2s/step - accuracy: 0.7743 - loss: 0.7052 - val_accuracy: 0.7799 - val_loss: 0.7057
# Epoch 43/100
# 2/2 - 3s - 2s/step - accuracy: 0.7743 - loss: 0.6779 - val_accuracy: 0.7887 - val_loss: 0.6786
# Epoch 44/100
# 2/2 - 4s - 2s/step - accuracy: 0.7822 - loss: 0.6648 - val_accuracy: 0.7889 - val_loss: 0.6629
# Epoch 45/100
# 2/2 - 3s - 2s/step - accuracy: 0.8020 - loss: 0.6448 - val_accuracy: 0.7898 - val_loss: 0.6741
# Epoch 46/100
# 2/2 - 3s - 2s/step - accuracy: 0.8178 - loss: 0.5799 - val_accuracy: 0.8041 - val_loss: 0.6247
# Epoch 47/100
# 2/2 - 3s - 2s/step - accuracy: 0.8119 - loss: 0.5819 - val_accuracy: 0.8046 - val_loss: 0.6233
# Epoch 48/100
# 2/2 - 4s - 2s/step - accuracy: 0.8139 - loss: 0.5865 - val_accuracy: 0.8178 - val_loss: 0.5767
# Epoch 49/100
# 2/2 - 3s - 2s/step - accuracy: 0.8198 - loss: 0.5460 - val_accuracy: 0.8226 - val_loss: 0.5721
# Epoch 50/100
# 2/2 - 3s - 2s/step - accuracy: 0.8416 - loss: 0.5148 - val_accuracy: 0.8316 - val_loss: 0.5721
# Epoch 51/100
# 2/2 - 3s - 2s/step - accuracy: 0.8218 - loss: 0.5300 - val_accuracy: 0.8256 - val_loss: 0.5618
# Epoch 52/100
# 2/2 - 5s - 3s/step - accuracy: 0.8317 - loss: 0.5025 - val_accuracy: 0.8364 - val_loss: 0.5485
# Epoch 53/100
# 2/2 - 3s - 2s/step - accuracy: 0.8436 - loss: 0.4746 - val_accuracy: 0.8453 - val_loss: 0.5160
# Epoch 54/100
# 2/2 - 3s - 2s/step - accuracy: 0.8574 - loss: 0.4693 - val_accuracy: 0.8517 - val_loss: 0.4939
# Epoch 55/100
# 2/2 - 4s - 2s/step - accuracy: 0.8634 - loss: 0.4704 - val_accuracy: 0.8560 - val_loss: 0.5074
# Epoch 56/100
# 2/2 - 5s - 2s/step - accuracy: 0.8713 - loss: 0.4191 - val_accuracy: 0.8617 - val_loss: 0.4873
# Epoch 57/100
# 2/2 - 3s - 2s/step - accuracy: 0.8673 - loss: 0.3937 - val_accuracy: 0.8578 - val_loss: 0.4945
# Epoch 58/100
# 2/2 - 3s - 2s/step - accuracy: 0.8851 - loss: 0.3794 - val_accuracy: 0.8558 - val_loss: 0.5051
# Epoch 59/100
# 2/2 - 5s - 3s/step - accuracy: 0.8792 - loss: 0.4196 - val_accuracy: 0.8549 - val_loss: 0.5118
# Epoch 60/100
# 2/2 - 5s - 3s/step - accuracy: 0.8792 - loss: 0.3593 - val_accuracy: 0.8621 - val_loss: 0.4960
# Epoch 61/100
# 2/2 - 3s - 2s/step - accuracy: 0.8693 - loss: 0.3566 - val_accuracy: 0.8670 - val_loss: 0.4954
# Epoch 62/100
# 2/2 - 4s - 2s/step - accuracy: 0.8733 - loss: 0.3762 - val_accuracy: 0.8761 - val_loss: 0.4696
# Epoch 63/100
# 2/2 - 3s - 2s/step - accuracy: 0.8911 - loss: 0.3513 - val_accuracy: 0.8766 - val_loss: 0.4695
# Epoch 64/100
# 2/2 - 3s - 2s/step - accuracy: 0.8812 - loss: 0.3355 - val_accuracy: 0.8746 - val_loss: 0.4744
# Epoch 65/100
# 2/2 - 4s - 2s/step - accuracy: 0.8851 - loss: 0.3412 - val_accuracy: 0.8749 - val_loss: 0.5239
# Epoch 66/100
# 2/2 - 4s - 2s/step - accuracy: 0.8970 - loss: 0.3195 - val_accuracy: 0.8841 - val_loss: 0.4278
# Epoch 67/100
# 2/2 - 6s - 3s/step - accuracy: 0.8812 - loss: 0.3290 - val_accuracy: 0.8735 - val_loss: 0.4844
# Epoch 68/100
# 2/2 - 6s - 3s/step - accuracy: 0.8950 - loss: 0.3200 - val_accuracy: 0.8894 - val_loss: 0.4263
# Epoch 69/100
# 2/2 - 3s - 2s/step - accuracy: 0.9010 - loss: 0.2802 - val_accuracy: 0.8788 - val_loss: 0.4380
# Epoch 70/100
# 2/2 - 3s - 2s/step - accuracy: 0.8990 - loss: 0.3035 - val_accuracy: 0.8786 - val_loss: 0.4488
# Epoch 71/100
# 2/2 - 5s - 3s/step - accuracy: 0.9168 - loss: 0.2702 - val_accuracy: 0.8864 - val_loss: 0.3932
# Epoch 72/100
# 2/2 - 3s - 2s/step - accuracy: 0.8990 - loss: 0.2657 - val_accuracy: 0.8899 - val_loss: 0.3726
# Epoch 73/100
# 2/2 - 3s - 2s/step - accuracy: 0.9168 - loss: 0.2403 - val_accuracy: 0.8920 - val_loss: 0.3707
# Epoch 74/100
# 2/2 - 3s - 2s/step - accuracy: 0.9188 - loss: 0.2395 - val_accuracy: 0.8898 - val_loss: 0.3813
# Epoch 75/100
# 2/2 - 3s - 2s/step - accuracy: 0.9109 - loss: 0.3104 - val_accuracy: 0.9028 - val_loss: 0.3580
# Epoch 76/100
# 2/2 - 3s - 2s/step - accuracy: 0.9168 - loss: 0.2656 - val_accuracy: 0.8978 - val_loss: 0.3856
# Epoch 77/100
# 2/2 - 3s - 2s/step - accuracy: 0.9050 - loss: 0.2434 - val_accuracy: 0.8922 - val_loss: 0.4061
# Epoch 78/100
# 2/2 - 3s - 2s/step - accuracy: 0.9248 - loss: 0.2335 - val_accuracy: 0.8819 - val_loss: 0.5113
# Epoch 79/100
# 2/2 - 5s - 3s/step - accuracy: 0.9307 - loss: 0.2377 - val_accuracy: 0.8834 - val_loss: 0.5050
# Epoch 80/100
# 2/2 - 3s - 2s/step - accuracy: 0.9267 - loss: 0.2185 - val_accuracy: 0.8966 - val_loss: 0.4167
# Epoch 81/100
# 2/2 - 3s - 2s/step - accuracy: 0.9109 - loss: 0.2329 - val_accuracy: 0.8869 - val_loss: 0.4233
# Epoch 82/100
# 2/2 - 5s - 3s/step - accuracy: 0.9188 - loss: 0.2261 - val_accuracy: 0.8925 - val_loss: 0.3944
# Epoch 83/100
# 2/2 - 4s - 2s/step - accuracy: 0.9307 - loss: 0.1998 - val_accuracy: 0.9062 - val_loss: 0.3193
# Epoch 84/100
# 2/2 - 3s - 2s/step - accuracy: 0.9228 - loss: 0.2109 - val_accuracy: 0.9091 - val_loss: 0.3127
# Epoch 85/100
# 2/2 - 5s - 3s/step - accuracy: 0.9366 - loss: 0.1733 - val_accuracy: 0.9035 - val_loss: 0.3303
# Epoch 86/100
# 2/2 - 3s - 2s/step - accuracy: 0.9307 - loss: 0.1995 - val_accuracy: 0.9162 - val_loss: 0.3272
# Epoch 87/100
# 2/2 - 3s - 2s/step - accuracy: 0.9406 - loss: 0.1846 - val_accuracy: 0.9236 - val_loss: 0.3120
# Epoch 88/100
# 2/2 - 3s - 2s/step - accuracy: 0.9366 - loss: 0.1748 - val_accuracy: 0.9261 - val_loss: 0.3165
# Epoch 89/100
# 2/2 - 5s - 3s/step - accuracy: 0.9426 - loss: 0.1884 - val_accuracy: 0.9263 - val_loss: 0.3471
# Epoch 90/100
# 2/2 - 4s - 2s/step - accuracy: 0.9446 - loss: 0.1842 - val_accuracy: 0.9258 - val_loss: 0.3717
# Epoch 91/100
# 2/2 - 3s - 2s/step - accuracy: 0.9446 - loss: 0.1836 - val_accuracy: 0.9236 - val_loss: 0.3916
# Epoch 92/100
# 2/2 - 3s - 2s/step - accuracy: 0.9446 - loss: 0.1736 - val_accuracy: 0.9200 - val_loss: 0.3609
# Epoch 93/100
# 2/2 - 3s - 2s/step - accuracy: 0.9426 - loss: 0.1485 - val_accuracy: 0.9212 - val_loss: 0.3947
# Epoch 94/100
# 2/2 - 4s - 2s/step - accuracy: 0.9505 - loss: 0.1678 - val_accuracy: 0.9213 - val_loss: 0.4573
# Epoch 95/100
# 2/2 - 3s - 2s/step - accuracy: 0.9426 - loss: 0.1591 - val_accuracy: 0.9335 - val_loss: 0.3371
# Epoch 96/100
# 2/2 - 5s - 3s/step - accuracy: 0.9386 - loss: 0.1680 - val_accuracy: 0.9268 - val_loss: 0.3667
# Epoch 97/100
# 2/2 - 3s - 2s/step - accuracy: 0.9525 - loss: 0.1578 - val_accuracy: 0.9262 - val_loss: 0.3308
# Epoch 98/100
# 2/2 - 3s - 2s/step - accuracy: 0.9347 - loss: 0.1772 - val_accuracy: 0.9282 - val_loss: 0.3178
# Epoch 99/100
# 2/2 - 3s - 2s/step - accuracy: 0.9683 - loss: 0.1291 - val_accuracy: 0.9294 - val_loss: 0.3439
# Epoch 100/100
# 2/2 - 3s - 2s/step - accuracy: 0.9564 - loss: 0.1350 - val_accuracy: 0.9378 - val_loss: 0.3229
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 198ms/step
# DONE.
# ZIP FILE: LhSSN_SA_Module_Output.zip
