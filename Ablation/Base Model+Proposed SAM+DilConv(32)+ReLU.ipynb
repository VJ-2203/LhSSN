# %%
# !pip install -q spectral einops thop

import os, time, zipfile, gc
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score, precision_recall_fscore_support
from tensorflow.keras.utils import to_categorical
import spectral

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 18.0 MB/s eta 0:00:00
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ===============================================================
# CONFIG (same style as LhSSN)
# ==============================================================

dataset = 'IP'
windowSize = 25
K = 30
epochs = 100
batch_size = 256
learning_rate = 0.001

split_mode = "ratio"          # ratio / count

train_ratio = 0.05           # if ratio
samples_per_class = 15       # if count

results_folder = "LhSSN_SA_Module_Output"
os.makedirs(results_folder, exist_ok=True)

base = "/content/drive/MyDrive/Colab Notebooks/dataset/"

# ===============================================================
# DATA LOADING
# ==============================================================

def loadData(name):
    if name == 'IP':
        data = sio.loadmat(base+'Indian_pines_corrected.mat')['indian_pines_corrected']
        labels = sio.loadmat(base+'Indian_pines_gt.mat')['indian_pines_gt']
    return data, labels

# ===============================================================
# PCA
# ==============================================================

def applyPCA(X, numComponents):
    reshaped = X.reshape(-1, X.shape[2])
    pca = PCA(n_components=numComponents, whiten=True)
    Xp = pca.fit_transform(reshaped)
    return Xp.reshape(X.shape[0], X.shape[1], numComponents)

# ===============================================================
# PATCH EXTRACTION
# ==============================================================

def padWithZeros(X, margin):
    return np.pad(X, ((margin,margin),(margin,margin),(0,0)), mode='constant')

def createImageCubes(X, y, windowSize=25):
    margin = windowSize // 2
    zeroPaddedX = padWithZeros(X, margin)

    patches = []
    labels = []

    for r in range(margin, zeroPaddedX.shape[0]-margin):
        for c in range(margin, zeroPaddedX.shape[1]-margin):

            patch = zeroPaddedX[r-margin:r+margin+1,
                                c-margin:c+margin+1]

            label = y[r-margin, c-margin]

            if label > 0:
                patches.append(patch)
                labels.append(label-1)

    return np.array(patches), np.array(labels)

# ===============================================================
# SPLIT
# ==============================================================

def splitTrainTestSet(X, y):

    np.random.seed(42)

    train_idx = []
    test_idx = []

    for cls in np.unique(y):

        idx = np.where(y == cls)[0]
        np.random.shuffle(idx)

        if split_mode == "ratio":
            n_train = max(1, int(len(idx)*train_ratio))
        else:
            n_train = min(samples_per_class, len(idx)-1)

        train_idx.extend(idx[:n_train])
        test_idx.extend(idx[n_train:])

    return X[train_idx], X[test_idx], y[train_idx], y[test_idx]

# ===============================================================
# LOAD DATA
# ==============================================================

X, y = loadData(dataset)
X = applyPCA(X, K)
X, y = createImageCubes(X, y, windowSize)

Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y)

num_classes = len(np.unique(y))

ytrain_cat = to_categorical(ytrain, num_classes)
ytest_cat = to_categorical(ytest, num_classes)

print("Train:", Xtrain.shape)
print("Test :", Xtest.shape)
# Out:
# Train: (505, 25, 25, 30)
# Test : (9744, 25, 25, 30)

# %%
# ===============================================================
# MODELLhSSN with conv Channel Attention
# ==============================================================

from tensorflow.keras import layers, models
from einops.layers.tensorflow import Rearrange
# --------- Build Model (EXACT architecture you used) ---------
def build_model(S, L, num_classes):
    inp = tf.keras.layers.Input((S, S, L, 1))
    # Block 1
    x = tf.keras.layers.Conv3D(filters=8,  kernel_size=(3,3,7), activation='relu')(inp)
    # Block 2
    x = tf.keras.layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu')(x)
    # Block 3
    x = tf.keras.layers.Conv3D(filters=32, kernel_size=(3,3,3), activation='relu')(x)
    # Block 4  (reshape to 2D convs)
    conv3d_shape = x.shape  # (None, H, W, D, C)
    x = tf.keras.layers.Reshape((conv3d_shape[1], conv3d_shape[2],
                                 conv3d_shape[3]*conv3d_shape[4]))(x)
    x = tf.keras.layers.Conv2D(filters=24,  kernel_size=(3,3), activation='relu')(x)
########################################################
    # Spatial Attention
    x1 = layers.BatchNormalization(name='BatchNormalization_4')(x)

    y1 = layers.MaxPooling2D((2, 2), padding="same", strides=(1, 1), name='MaxPooling2D_y1')(x1)
    y2 = layers.AvgPool2D((2, 2), padding="same", strides=(1, 1), name='AvgPool2D_y2')(x1)
    concat = layers.Concatenate()([y1, y2])

    y4 = layers.Conv2D(32, (3, 3), padding='same', dilation_rate=2, name='Conv2D_y2')(concat)

    y4 = layers.BatchNormalization(name='BatchNormalization_y')(y4)
    y4 = layers.ReLU()(y4)
    #y4 = layers.geLU()(y4)

    # Channel Attention
    # Skip Connection (M)
    concat_m = layers.Concatenate()([y4, x1])
    z = layers.MaxPooling2D((2, 2), strides=(2, 2), name='MaxPooling2D_z')(concat_m)
    z = tf.keras.layers.GlobalAveragePooling2D()(z)

#################################################

    # Block 5
    x = tf.keras.layers.Conv2D(filters=96,  kernel_size=(3,3), activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    # Block 6
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Block 7
    x = layers.Concatenate()([x, z])


    # Block 7
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    # Output Layer
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    # Adam 0.001 as in your code
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])
    return model

model = build_model(windowSize, K, num_classes)

# Save Summary
with open(results_folder+"/model_summary.txt","w") as f:
    model.summary(print_fn=lambda x: f.write(x+"\n"))

model.summary()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 25, 25,    │          0 │ -                 │
# │ (InputLayer)        │ 30, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 23, 23,    │        512 │ input_layer_2[0]… │
# │                     │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 21, 21,    │      5,776 │ conv3d_6[0][0]    │
# │                     │ 20, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 19, 19,    │     13,856 │ conv3d_7[0][0]    │
# │                     │ 18, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 19, 19,    │          0 │ conv3d_8[0][0]    │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 17, 17,    │    124,440 │ reshape_2[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 17, 17,    │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_y1     │ (None, 17, 17,    │          0 │ BatchNormalizati… │
# │ (MaxPooling2D)      │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ AvgPool2D_y2        │ (None, 17, 17,    │          0 │ BatchNormalizati… │
# │ (AveragePooling2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 17, 17,    │          0 │ MaxPooling2D_y1[… │
# │ (Concatenate)       │ 48)               │            │ AvgPool2D_y2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv2D_y2 (Conv2D)  │ (None, 17, 17,    │     13,856 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 17, 17,    │        128 │ Conv2D_y2[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 15, 15,    │     20,832 │ conv2d_6[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 17, 17,    │          0 │ BatchNormalizati… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 7, 7, 96)  │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 17, 17,    │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 56)               │            │ BatchNormalizati… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 5, 5, 128) │    110,720 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_z      │ (None, 8, 8, 56)  │          0 │ concatenate_7[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_8[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 56)        │          0 │ MaxPooling2D_z[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 184)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     23,680 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 16)        │      1,040 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 323,192 (1.23 MB)
#  Trainable params: 323,080 (1.23 MB)
#  Non-trainable params: 112 (448.00 B)

# %%
# ===============================================================
# MODELLhSSN with SA at 7X7 padding 1 and filters 32
# ==============================================================

from tensorflow.keras import layers, models
from einops.layers.tensorflow import Rearrange
# --------- Build Model (EXACT architecture you used) ---------
def build_model(S, L, num_classes):
    inp = tf.keras.layers.Input((S, S, L, 1))
    # Block 1
    x = tf.keras.layers.Conv3D(filters=8,  kernel_size=(3,3,7), activation='relu')(inp)
    # Block 2
    x = tf.keras.layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu')(x)
    # Block 3
    x = tf.keras.layers.Conv3D(filters=32, kernel_size=(3,3,3), activation='relu')(x)
    # Block 4  (reshape to 2D convs)
    conv3d_shape = x.shape  # (None, H, W, D, C)
    x = tf.keras.layers.Reshape((conv3d_shape[1], conv3d_shape[2],
                                 conv3d_shape[3]*conv3d_shape[4]))(x)
    x = tf.keras.layers.Conv2D(filters=24,  kernel_size=(3,3), activation='relu')(x)


    # Block 5
    x = tf.keras.layers.Conv2D(filters=96,  kernel_size=(3,3), activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    # Block 6
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Block 7
    x = layers.Concatenate()([x, z])


    # Block 7
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    # Output Layer
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    # Adam 0.001 as in your code
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])
    return model

model = build_model(windowSize, K, num_classes)

# Save Summary
with open(results_folder+"/model_summary.txt","w") as f:
    model.summary(print_fn=lambda x: f.write(x+"\n"))

model.summary()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 25, 25,    │          0 │ -                 │
# │ (InputLayer)        │ 30, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 23, 23,    │        512 │ input_layer_3[0]… │
# │                     │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 21, 21,    │      5,776 │ conv3d_9[0][0]    │
# │                     │ 20, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 19, 19,    │     13,856 │ conv3d_10[0][0]   │
# │                     │ 18, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 19, 19,    │          0 │ conv3d_11[0][0]   │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 17, 17,    │    124,440 │ reshape_3[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 15, 15,    │     20,832 │ conv2d_6[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 7, 7, 96)  │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 7, 7, 96)  │        384 │ max_pooling2d_3[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_y1     │ (None, 7, 7, 96)  │          0 │ BatchNormalizati… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ AvgPool2D_y2        │ (None, 7, 7, 96)  │          0 │ BatchNormalizati… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 7, 7, 192) │          0 │ MaxPooling2D_y1[… │
# │ (Concatenate)       │                   │            │ AvgPool2D_y2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv2D_y2 (Conv2D)  │ (None, 7, 7, 32)  │     55,328 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 7, 7, 32)  │        128 │ Conv2D_y2[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 7, 7, 32)  │          0 │ BatchNormalizati… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 5, 5, 128) │    110,720 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 7, 7, 128) │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │                   │            │ BatchNormalizati… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_8[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ concatenate_5[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     32,896 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      1,040 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 374,168 (1.43 MB)
#  Trainable params: 373,912 (1.43 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
# ===============================================================
# MODELLhSSN with conv Channel Attention
# ==============================================================

from tensorflow.keras import layers, models
from einops.layers.tensorflow import Rearrange
# --------- Build Model (EXACT architecture you used) ---------
def build_model(S, L, num_classes):
    inp = tf.keras.layers.Input((S, S, L, 1))
    # Block 1
    x = tf.keras.layers.Conv3D(filters=8,  kernel_size=(3,3,7), activation='relu')(inp)
    # Block 2
    x = tf.keras.layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu')(x)
    # Block 3
    x = tf.keras.layers.Conv3D(filters=32, kernel_size=(3,3,3), activation='relu')(x)
    # Block 4  (reshape to 2D convs)
    conv3d_shape = x.shape  # (None, H, W, D, C)
    x = tf.keras.layers.Reshape((conv3d_shape[1], conv3d_shape[2],
                                 conv3d_shape[3]*conv3d_shape[4]))(x)
    x = tf.keras.layers.Conv2D(filters=24,  kernel_size=(3,3), activation='relu')(x)


    # Block 5
    x = tf.keras.layers.Conv2D(filters=96,  kernel_size=(3,3), activation='relu')(x)
    ########################################################
    # Spatial Attention
    x1 = layers.BatchNormalization(name='BatchNormalization_4')(x)

    y1 = layers.MaxPooling2D((2, 2), padding="same", strides=(1, 1), name='MaxPooling2D_y1')(x1)
    y2 = layers.AvgPool2D((2, 2), padding="same", strides=(1, 1), name='AvgPool2D_y2')(x1)
    concat = layers.Concatenate()([y1, y2])

    y4 = layers.Conv2D(32, (3, 3), padding='valid', dilation_rate=2, name='Conv2D_y2')(concat)

    y4 = layers.BatchNormalization(name='BatchNormalization_y')(y4)
    y4 = layers.ReLU()(y4)
    #y4 = layers.geLU()(y4)

    # Channel Attention
    # Skip Connection (M)
    #concat_m = layers.Concatenate()([y4, x1])
    z = layers.MaxPooling2D((2, 2), strides=(2, 2), name='MaxPooling2D_z')(y4)
    z = tf.keras.layers.GlobalAveragePooling2D()(z)

#################################################
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    # Block 6
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Block 7
    x = layers.Concatenate()([x, z])


    # Block 7
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    # Output Layer
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    # Adam 0.001 as in your code
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])
    return model

model = build_model(windowSize, K, num_classes)

# Save Summary
with open(results_folder+"/model_summary.txt","w") as f:
    model.summary(print_fn=lambda x: f.write(x+"\n"))

model.summary()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 25, 25,    │          0 │ -                 │
# │ (InputLayer)        │ 30, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_21 (Conv3D)  │ (None, 23, 23,    │        512 │ input_layer_7[0]… │
# │                     │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_22 (Conv3D)  │ (None, 21, 21,    │      5,776 │ conv3d_21[0][0]   │
# │                     │ 20, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_23 (Conv3D)  │ (None, 19, 19,    │     13,856 │ conv3d_22[0][0]   │
# │                     │ 18, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 19, 19,    │          0 │ conv3d_23[0][0]   │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 17, 17,    │    124,440 │ reshape_7[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 15, 15,    │     20,832 │ conv2d_18[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 15, 15,    │        384 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_y1     │ (None, 15, 15,    │          0 │ BatchNormalizati… │
# │ (MaxPooling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ AvgPool2D_y2        │ (None, 15, 15,    │          0 │ BatchNormalizati… │
# │ (AveragePooling2D)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 15, 15,    │          0 │ MaxPooling2D_y1[… │
# │ (Concatenate)       │ 192)              │            │ AvgPool2D_y2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv2D_y2 (Conv2D)  │ (None, 11, 11,    │     55,328 │ concatenate_14[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNormalization… │ (None, 11, 11,    │        128 │ Conv2D_y2[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 7, 7, 96)  │          0 │ conv2d_19[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 11, 11,    │          0 │ BatchNormalizati… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 5, 5, 128) │    110,720 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MaxPooling2D_z      │ (None, 5, 5, 32)  │          0 │ re_lu_6[0][0]     │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_20[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ MaxPooling2D_z[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 160)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │     20,608 │ concatenate_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128)       │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 64)        │      8,256 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 64)        │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 16)        │      1,040 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 361,880 (1.38 MB)
#  Trainable params: 361,624 (1.38 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
#from tensorflow.keras.utils import plot_model
from keras.utils import plot_model, to_categorical
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# ===============================================================
# TRAIN
# ==============================================================

tic = time.time()

history = model.fit(
    Xtrain, ytrain_cat,
    validation_data=(Xtest, ytest_cat),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2
)

toc = time.time()

train_time = toc - tic

# Save history
np.save(results_folder+"/history.npy", history.history)

# ===============================================================
# PLOTS
# ==============================================================

def save_plot(a,b,title,name):

    plt.figure(figsize=(8,6))
    plt.plot(history.history[a], label='Train')
    plt.plot(history.history[b], label='Validation')
    plt.xlabel("Epochs")
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.savefig(results_folder+"/"+name+".png", dpi=300)
    plt.show()

save_plot("loss","val_loss","Loss Curve","loss_curve")
save_plot("accuracy","val_accuracy","Accuracy Curve","accuracy_curve")

# ===============================================================
# EVALUATION
# ==============================================================

tic = time.time()

pred = model.predict(Xtest)

toc = time.time()

test_time = toc - tic

y_pred = np.argmax(pred, axis=1)

oa = accuracy_score(ytest, y_pred)
kappa = cohen_kappa_score(ytest, y_pred)

cm = confusion_matrix(ytest, y_pred)

each_acc = np.diag(cm)/cm.sum(axis=1)
aa = np.mean(each_acc)

precision, recall, f1, _ = precision_recall_fscore_support(
    ytest, y_pred, average='weighted'
)

# ===============================================================
# SAVE REPORT
# ==============================================================

with open(results_folder+"/results.txt","w") as f:

    f.write(f"Training Time: {train_time:.2f}s\n")
    f.write(f"Testing Time: {test_time:.2f}s\n")
    f.write(f"OA: {oa*100:.2f}\n")
    f.write(f"AA: {aa*100:.2f}\n")
    f.write(f"Kappa: {kappa*100:.2f}\n")
    f.write(f"Precision: {precision*100:.2f}\n")
    f.write(f"Recall: {recall*100:.2f}\n")
    f.write(f"F1-score: {f1*100:.2f}\n\n")

    f.write(classification_report(ytest, y_pred))

# ===============================================================
# CLASSIFICATION MAP
# ==============================================================

Xfull, yfull = loadData(dataset)
Xfull = applyPCA(Xfull, K)

margin = windowSize//2
Xpad = padWithZeros(Xfull, margin)

outputs = np.zeros(yfull.shape)

patches = []
coords = []

for i in range(yfull.shape[0]):
    for j in range(yfull.shape[1]):

        if yfull[i,j] > 0:

            patch = Xpad[i:i+windowSize, j:j+windowSize]
            patches.append(patch)
            coords.append((i,j))

patches = np.array(patches)

pred = model.predict(patches, batch_size=512)
pred = np.argmax(pred, axis=1)

for (i,j),p in zip(coords,pred):
    outputs[i,j] = p+1

spectral.save_rgb(
    results_folder+"/classified_map.jpg",
    outputs.astype(int),
    colors=spectral.spy_colors
)

spectral.save_rgb(
    results_folder+"/ground_truth.jpg",
    yfull.astype(int),
    colors=spectral.spy_colors
)

# ===============================================================
# ZIP
# ==============================================================

zip_name = "LhSSN_SA_Module_Output.zip"

with zipfile.ZipFile(zip_name,'w') as zipf:
    for file in os.listdir(results_folder):
        zipf.write(results_folder+"/"+file, arcname=file)

print("DONE.")
print("ZIP FILE:", zip_name)
# Out:
# Epoch 1/100
# 2/2 - 23s - 11s/step - accuracy: 0.1109 - loss: 2.7061 - val_accuracy: 0.2317 - val_loss: 2.7137
# Epoch 2/100
# 2/2 - 4s - 2s/step - accuracy: 0.2257 - loss: 2.4604 - val_accuracy: 0.1234 - val_loss: 2.6272
# Epoch 3/100
# 2/2 - 3s - 2s/step - accuracy: 0.2851 - loss: 2.3081 - val_accuracy: 0.1425 - val_loss: 2.5502
# Epoch 4/100
# 2/2 - 3s - 2s/step - accuracy: 0.3564 - loss: 2.1374 - val_accuracy: 0.3065 - val_loss: 2.4580
# Epoch 5/100
# 2/2 - 6s - 3s/step - accuracy: 0.3901 - loss: 2.0318 - val_accuracy: 0.3857 - val_loss: 2.3620
# Epoch 6/100
# 2/2 - 3s - 2s/step - accuracy: 0.4317 - loss: 1.8884 - val_accuracy: 0.3769 - val_loss: 2.2896
# Epoch 7/100
# 2/2 - 3s - 2s/step - accuracy: 0.4554 - loss: 1.7610 - val_accuracy: 0.3332 - val_loss: 2.1936
# Epoch 8/100
# 2/2 - 3s - 2s/step - accuracy: 0.4832 - loss: 1.6718 - val_accuracy: 0.4262 - val_loss: 2.1363
# Epoch 9/100
# 2/2 - 3s - 2s/step - accuracy: 0.5327 - loss: 1.5725 - val_accuracy: 0.4982 - val_loss: 2.0344
# Epoch 10/100
# 2/2 - 3s - 2s/step - accuracy: 0.5762 - loss: 1.4378 - val_accuracy: 0.5085 - val_loss: 1.8109
# Epoch 11/100
# 2/2 - 3s - 2s/step - accuracy: 0.5624 - loss: 1.4072 - val_accuracy: 0.6123 - val_loss: 1.8365
# Epoch 12/100
# 2/2 - 3s - 2s/step - accuracy: 0.6079 - loss: 1.3105 - val_accuracy: 0.6025 - val_loss: 1.6764
# Epoch 13/100
# 2/2 - 3s - 2s/step - accuracy: 0.6436 - loss: 1.2283 - val_accuracy: 0.6331 - val_loss: 1.5112
# Epoch 14/100
# 2/2 - 3s - 2s/step - accuracy: 0.6634 - loss: 1.1417 - val_accuracy: 0.6681 - val_loss: 1.3663
# Epoch 15/100
# 2/2 - 3s - 2s/step - accuracy: 0.6772 - loss: 1.0653 - val_accuracy: 0.7284 - val_loss: 1.2729
# Epoch 16/100
# 2/2 - 3s - 2s/step - accuracy: 0.6990 - loss: 1.0202 - val_accuracy: 0.7396 - val_loss: 1.1822
# Epoch 17/100
# 2/2 - 3s - 2s/step - accuracy: 0.7149 - loss: 0.9382 - val_accuracy: 0.7626 - val_loss: 1.0683
# Epoch 18/100
# 2/2 - 3s - 2s/step - accuracy: 0.7505 - loss: 0.8835 - val_accuracy: 0.7743 - val_loss: 1.0314
# Epoch 19/100
# 2/2 - 3s - 2s/step - accuracy: 0.7703 - loss: 0.8229 - val_accuracy: 0.6983 - val_loss: 0.9610
# Epoch 20/100
# 2/2 - 3s - 2s/step - accuracy: 0.7683 - loss: 0.7545 - val_accuracy: 0.7608 - val_loss: 0.9521
# Epoch 21/100
# 2/2 - 6s - 3s/step - accuracy: 0.7822 - loss: 0.7403 - val_accuracy: 0.8102 - val_loss: 0.7801
# Epoch 22/100
# 2/2 - 3s - 2s/step - accuracy: 0.8277 - loss: 0.6333 - val_accuracy: 0.8044 - val_loss: 0.7674
# Epoch 23/100
# 2/2 - 3s - 2s/step - accuracy: 0.8337 - loss: 0.6244 - val_accuracy: 0.8115 - val_loss: 0.6784
# Epoch 24/100
# 2/2 - 3s - 2s/step - accuracy: 0.8317 - loss: 0.5612 - val_accuracy: 0.7975 - val_loss: 0.7059
# Epoch 25/100
# 2/2 - 3s - 2s/step - accuracy: 0.8297 - loss: 0.5646 - val_accuracy: 0.8592 - val_loss: 0.5606
# Epoch 26/100
# 2/2 - 3s - 2s/step - accuracy: 0.8574 - loss: 0.5020 - val_accuracy: 0.8161 - val_loss: 0.5851
# Epoch 27/100
# 2/2 - 3s - 2s/step - accuracy: 0.8515 - loss: 0.4863 - val_accuracy: 0.8559 - val_loss: 0.5172
# Epoch 28/100
# 2/2 - 3s - 2s/step - accuracy: 0.8693 - loss: 0.4825 - val_accuracy: 0.8628 - val_loss: 0.5888
# Epoch 29/100
# 2/2 - 3s - 2s/step - accuracy: 0.8832 - loss: 0.4424 - val_accuracy: 0.8036 - val_loss: 0.6595
# Epoch 30/100
# 2/2 - 3s - 2s/step - accuracy: 0.9030 - loss: 0.3989 - val_accuracy: 0.8945 - val_loss: 0.4297
# Epoch 31/100
# 2/2 - 3s - 2s/step - accuracy: 0.8891 - loss: 0.4108 - val_accuracy: 0.9052 - val_loss: 0.4066
# Epoch 32/100
# 2/2 - 3s - 2s/step - accuracy: 0.9109 - loss: 0.3191 - val_accuracy: 0.8375 - val_loss: 0.5108
# Epoch 33/100
# 2/2 - 3s - 2s/step - accuracy: 0.8970 - loss: 0.3483 - val_accuracy: 0.9070 - val_loss: 0.3917
# Epoch 34/100
# 2/2 - 3s - 2s/step - accuracy: 0.9228 - loss: 0.2964 - val_accuracy: 0.9176 - val_loss: 0.3370
# Epoch 35/100
# 2/2 - 3s - 2s/step - accuracy: 0.9248 - loss: 0.2671 - val_accuracy: 0.9065 - val_loss: 0.3614
# Epoch 36/100
# 2/2 - 3s - 2s/step - accuracy: 0.9168 - loss: 0.2901 - val_accuracy: 0.9338 - val_loss: 0.2843
# Epoch 37/100
# 2/2 - 3s - 2s/step - accuracy: 0.9347 - loss: 0.2317 - val_accuracy: 0.9212 - val_loss: 0.3130
# Epoch 38/100
# 2/2 - 3s - 2s/step - accuracy: 0.9168 - loss: 0.2806 - val_accuracy: 0.9000 - val_loss: 0.3404
# Epoch 39/100
# 2/2 - 3s - 2s/step - accuracy: 0.9267 - loss: 0.2449 - val_accuracy: 0.9243 - val_loss: 0.2979
# Epoch 40/100
# 2/2 - 3s - 2s/step - accuracy: 0.9327 - loss: 0.2270 - val_accuracy: 0.9315 - val_loss: 0.2738
# Epoch 41/100
# 2/2 - 3s - 2s/step - accuracy: 0.9485 - loss: 0.1996 - val_accuracy: 0.9398 - val_loss: 0.2566
# Epoch 42/100
# 2/2 - 3s - 2s/step - accuracy: 0.9485 - loss: 0.1932 - val_accuracy: 0.9361 - val_loss: 0.2559
# Epoch 43/100
# 2/2 - 3s - 2s/step - accuracy: 0.9545 - loss: 0.1818 - val_accuracy: 0.9368 - val_loss: 0.2407
# Epoch 44/100
# 2/2 - 3s - 2s/step - accuracy: 0.9545 - loss: 0.1603 - val_accuracy: 0.9375 - val_loss: 0.2374
# Epoch 45/100
# 2/2 - 3s - 2s/step - accuracy: 0.9545 - loss: 0.1492 - val_accuracy: 0.9410 - val_loss: 0.2324
# Epoch 46/100
# 2/2 - 3s - 2s/step - accuracy: 0.9604 - loss: 0.1416 - val_accuracy: 0.9450 - val_loss: 0.2179
# Epoch 47/100
# 2/2 - 3s - 2s/step - accuracy: 0.9525 - loss: 0.1689 - val_accuracy: 0.9419 - val_loss: 0.2240
# Epoch 48/100
# 2/2 - 3s - 2s/step - accuracy: 0.9644 - loss: 0.1270 - val_accuracy: 0.9253 - val_loss: 0.2841
# Epoch 49/100
# 2/2 - 3s - 2s/step - accuracy: 0.9624 - loss: 0.1349 - val_accuracy: 0.9315 - val_loss: 0.2720
# Epoch 50/100
# 2/2 - 3s - 2s/step - accuracy: 0.9663 - loss: 0.1328 - val_accuracy: 0.9431 - val_loss: 0.2082
# Epoch 51/100
# 2/2 - 3s - 2s/step - accuracy: 0.9545 - loss: 0.1504 - val_accuracy: 0.9454 - val_loss: 0.2074
# Epoch 52/100
# 2/2 - 3s - 2s/step - accuracy: 0.9703 - loss: 0.1037 - val_accuracy: 0.8983 - val_loss: 0.4624
# Epoch 53/100
# 2/2 - 3s - 2s/step - accuracy: 0.9624 - loss: 0.1478 - val_accuracy: 0.9379 - val_loss: 0.2239
# Epoch 54/100
# 2/2 - 3s - 2s/step - accuracy: 0.9663 - loss: 0.1260 - val_accuracy: 0.9400 - val_loss: 0.2473
# Epoch 55/100
# 2/2 - 3s - 2s/step - accuracy: 0.9505 - loss: 0.1561 - val_accuracy: 0.8990 - val_loss: 0.3678
# Epoch 56/100
# 2/2 - 3s - 2s/step - accuracy: 0.9485 - loss: 0.1630 - val_accuracy: 0.9206 - val_loss: 0.3076
# Epoch 57/100
# 2/2 - 3s - 2s/step - accuracy: 0.9723 - loss: 0.1115 - val_accuracy: 0.9387 - val_loss: 0.2384
# Epoch 58/100
# 2/2 - 3s - 2s/step - accuracy: 0.9743 - loss: 0.1105 - val_accuracy: 0.9466 - val_loss: 0.1991
# Epoch 59/100
# 2/2 - 3s - 2s/step - accuracy: 0.9644 - loss: 0.1223 - val_accuracy: 0.9460 - val_loss: 0.1976
# Epoch 60/100
# 2/2 - 3s - 2s/step - accuracy: 0.9683 - loss: 0.1043 - val_accuracy: 0.9420 - val_loss: 0.2116
# Epoch 61/100
# 2/2 - 6s - 3s/step - accuracy: 0.9703 - loss: 0.0960 - val_accuracy: 0.9348 - val_loss: 0.2385
# Epoch 62/100
# 2/2 - 3s - 2s/step - accuracy: 0.9723 - loss: 0.1035 - val_accuracy: 0.9397 - val_loss: 0.2306
# Epoch 63/100
# 2/2 - 3s - 2s/step - accuracy: 0.9762 - loss: 0.0807 - val_accuracy: 0.9480 - val_loss: 0.2152
# Epoch 64/100
# 2/2 - 3s - 2s/step - accuracy: 0.9703 - loss: 0.0878 - val_accuracy: 0.9523 - val_loss: 0.1955
# Epoch 65/100
# 2/2 - 3s - 2s/step - accuracy: 0.9762 - loss: 0.0819 - val_accuracy: 0.9525 - val_loss: 0.1790
# Epoch 66/100
# 2/2 - 3s - 2s/step - accuracy: 0.9683 - loss: 0.1113 - val_accuracy: 0.9611 - val_loss: 0.1537
# Epoch 67/100
# 2/2 - 3s - 2s/step - accuracy: 0.9743 - loss: 0.0736 - val_accuracy: 0.9576 - val_loss: 0.1680
# Epoch 68/100
# 2/2 - 6s - 3s/step - accuracy: 0.9743 - loss: 0.0909 - val_accuracy: 0.9564 - val_loss: 0.1746
# Epoch 69/100
# 2/2 - 3s - 2s/step - accuracy: 0.9802 - loss: 0.0638 - val_accuracy: 0.9562 - val_loss: 0.1990
# Epoch 70/100
# 2/2 - 3s - 2s/step - accuracy: 0.9743 - loss: 0.0786 - val_accuracy: 0.9573 - val_loss: 0.1880
# Epoch 71/100
# 2/2 - 3s - 2s/step - accuracy: 0.9762 - loss: 0.0733 - val_accuracy: 0.9650 - val_loss: 0.1573
# Epoch 72/100
# 2/2 - 5s - 3s/step - accuracy: 0.9802 - loss: 0.0658 - val_accuracy: 0.9515 - val_loss: 0.1950
# Epoch 73/100
# 2/2 - 3s - 2s/step - accuracy: 0.9703 - loss: 0.0922 - val_accuracy: 0.9583 - val_loss: 0.1688
# Epoch 74/100
# 2/2 - 3s - 2s/step - accuracy: 0.9822 - loss: 0.0598 - val_accuracy: 0.9621 - val_loss: 0.1577
# Epoch 75/100
# 2/2 - 3s - 2s/step - accuracy: 0.9881 - loss: 0.0458 - val_accuracy: 0.9613 - val_loss: 0.1681
# Epoch 76/100
# 2/2 - 3s - 2s/step - accuracy: 0.9743 - loss: 0.0949 - val_accuracy: 0.9627 - val_loss: 0.1639
# Epoch 77/100
# 2/2 - 3s - 2s/step - accuracy: 0.9822 - loss: 0.0697 - val_accuracy: 0.9594 - val_loss: 0.1640
# Epoch 78/100
# 2/2 - 3s - 2s/step - accuracy: 0.9802 - loss: 0.0630 - val_accuracy: 0.9481 - val_loss: 0.2085
# Epoch 79/100
# 2/2 - 3s - 2s/step - accuracy: 0.9842 - loss: 0.0555 - val_accuracy: 0.9549 - val_loss: 0.1861
# Epoch 80/100
# 2/2 - 3s - 2s/step - accuracy: 0.9802 - loss: 0.0556 - val_accuracy: 0.9639 - val_loss: 0.1514
# Epoch 81/100
# 2/2 - 3s - 2s/step - accuracy: 0.9842 - loss: 0.0652 - val_accuracy: 0.9640 - val_loss: 0.1464
# Epoch 82/100
# 2/2 - 3s - 2s/step - accuracy: 0.9782 - loss: 0.0743 - val_accuracy: 0.9637 - val_loss: 0.1527
# Epoch 83/100
# 2/2 - 4s - 2s/step - accuracy: 0.9881 - loss: 0.0415 - val_accuracy: 0.9604 - val_loss: 0.1734
# Epoch 84/100
# 2/2 - 3s - 2s/step - accuracy: 0.9762 - loss: 0.0593 - val_accuracy: 0.9607 - val_loss: 0.1795
# Epoch 85/100
# 2/2 - 3s - 2s/step - accuracy: 0.9822 - loss: 0.0402 - val_accuracy: 0.9602 - val_loss: 0.1836
# Epoch 86/100
# 2/2 - 3s - 2s/step - accuracy: 0.9881 - loss: 0.0405 - val_accuracy: 0.9597 - val_loss: 0.1883
# Epoch 87/100
# 2/2 - 6s - 3s/step - accuracy: 0.9861 - loss: 0.0468 - val_accuracy: 0.9613 - val_loss: 0.1888
# Epoch 88/100
# 2/2 - 3s - 2s/step - accuracy: 0.9842 - loss: 0.0427 - val_accuracy: 0.9587 - val_loss: 0.1988
# Epoch 89/100
# 2/2 - 6s - 3s/step - accuracy: 0.9901 - loss: 0.0373 - val_accuracy: 0.9598 - val_loss: 0.1845
# Epoch 90/100
# 2/2 - 3s - 2s/step - accuracy: 0.9842 - loss: 0.0349 - val_accuracy: 0.9605 - val_loss: 0.1686
# Epoch 91/100
# 2/2 - 3s - 2s/step - accuracy: 0.9822 - loss: 0.0550 - val_accuracy: 0.9617 - val_loss: 0.1913
# Epoch 92/100
# 2/2 - 3s - 2s/step - accuracy: 0.9782 - loss: 0.0559 - val_accuracy: 0.9622 - val_loss: 0.2000
# Epoch 93/100
# 2/2 - 3s - 2s/step - accuracy: 0.9861 - loss: 0.0355 - val_accuracy: 0.9633 - val_loss: 0.1846
# Epoch 94/100
# 2/2 - 3s - 2s/step - accuracy: 0.9921 - loss: 0.0371 - val_accuracy: 0.9631 - val_loss: 0.1832
# Epoch 95/100
# 2/2 - 3s - 2s/step - accuracy: 0.9881 - loss: 0.0485 - val_accuracy: 0.9587 - val_loss: 0.1952
# Epoch 96/100
# 2/2 - 3s - 2s/step - accuracy: 0.9921 - loss: 0.0524 - val_accuracy: 0.9487 - val_loss: 0.2257
# Epoch 97/100
# 2/2 - 3s - 2s/step - accuracy: 0.9881 - loss: 0.0442 - val_accuracy: 0.9515 - val_loss: 0.2278
# Epoch 98/100
# 2/2 - 3s - 2s/step - accuracy: 0.9861 - loss: 0.0316 - val_accuracy: 0.9558 - val_loss: 0.2102
# Epoch 99/100
# 2/2 - 3s - 2s/step - accuracy: 0.9881 - loss: 0.0508 - val_accuracy: 0.9622 - val_loss: 0.1678
# Epoch 100/100
# 2/2 - 3s - 2s/step - accuracy: 0.9921 - loss: 0.0421 - val_accuracy: 0.9570 - val_loss: 0.1775
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step
# DONE.
# ZIP FILE: LhSSN_SA_Module_Output.zip
